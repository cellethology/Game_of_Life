# %%
import pandas as pd

# 1. 读取结果文件
path = "results_18_settings_20251127_090039.csv"  # 如有需要加上完整路径
df = pd.read_csv(path)
print(df.head())
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       3 # 1. 读取结果文件
#       4 path = "results_18_settings_20251127_090039.csv"  # 如有需要加上完整路径
#
# ModuleNotFoundError: No module named 'pandas'
